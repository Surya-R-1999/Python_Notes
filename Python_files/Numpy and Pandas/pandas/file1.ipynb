# %% [markdown]
# if first word of series is 'l or a or d' return hi else return nothing

# %%
df_series = pd.read_csv('NbaInfo.csv',usecols=['Name']).squeeze()

# %%
df_series
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
df_series.dropna(inplace= True)

# %%
list1 = []
for i in range(len(df_series)):
    if df_series[i][0] in ['L','A','D']:
        list1.append('Hi')
    else:
        list1.append('Nothing')

df_series = pd.Series(list1)
print(df_series)
# Out:
# 0           Hi
# 1      Nothing
# 2      Nothing
# 3      Nothing
# 4      Nothing
#         ...
# 452    Nothing
# 453    Nothing
# 454    Nothing
# 455    Nothing
# 456    Nothing
# Length: 457, dtype: object
# Nothing    362
# Hi          95
# dtype: int64

# %%
df_series.value_counts()
# Out:
# Nothing    362
# Hi          95
# dtype: int64

# %%
df = pd.read_csv('NbaInfo.csv')

df_series = pd.Series(df['Name'])

df_series.dropna(inplace = True)

df_series = df_series.apply(lambda x : 'Hi' if x[0] in ['L','A','D'] else 'Nothing')

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df2  = df[:]

# %%
df2["Height"] = df2['Height'].apply(lambda x : float(str(x).replace("-",".")))

# %%
df2.Height
# Out:
# 0      6.2
# 1      6.6
# 2      6.5
# 3      6.5
# 4      6.1
#       ...
# 453    6.3
# 454    6.1
# 455    7.3
# 456    7.0
# 457    NaN
# Name: Height, Length: 458, dtype: float64

# %%
df2[(df2["Position"] == "PG") & (df2["Height"] > 6.2)]
# Out:
#                         Name                    Team  Number Position   Age  \
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 19              Jarrett Jack           Brooklyn Nets     2.0       PG  32.0
# 28              Donald Sloan           Brooklyn Nets    15.0       PG  28.0
# 34             Jose Calderon         New York Knicks     3.0       PG  34.0
# 37              Jerian Grant         New York Knicks    13.0       PG  23.0
# 53          Kendall Marshall      Philadelphia 76ers     5.0       PG  24.0
# 66               Cory Joseph         Toronto Raptors     6.0       PG  24.0
# 75              Delon Wright         Toronto Raptors    55.0       PG  24.0
# 80             Stephen Curry   Golden State Warriors    30.0       PG  28.0
# 84          Shaun Livingston   Golden State Warriors    34.0       PG  30.0
# 102           Pablo Prigioni    Los Angeles Clippers     9.0       PG  39.0
# ...

# %%
dictionary = {'name':['a','b','c','d','e'],'id_' : [1,2,3,4,5]}

# %%
df = pd.DataFrame(dictionary)

# %%
df.set_index("id_")
# Out:
#     name
# id_
# 1      a
# 2      b
# 3      c
# 4      d
# 5      e

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.loc[len(df)] = ['a',6]

# %%
df
# Out:
#   name  id_
# 0    a    1
# 1    b    2
# 2    c    3
# 3    d    4
# 4    e    5
# 5    b    6
# 6    b    6
# 7    b    6
# 8    b    6
# 9    a    6

# %%
df['name'].drop_duplicates(keep = False)
# Out:
# 2    c
# 3    d
# 4    e
# Name: name, dtype: object

# %%
df[df['name'].duplicated(keep = False)]
# Out:
#   name  id_
# 0    a    1
# 1    b    2
# 5    b    6
# 6    b    6
# 7    b    6
# 8    b    6
# 9    a    6

# %%
class Employee:
    def __init__(self, name, base_pay):
        self.name = name
        self.base_pay = base_pay

    def get_pay(self):
        return self.base_pay


class SalesEmployee(Employee):
    def __init__(self, name, base_pay, sales_incentive):
        self.name = name
        self.base_pay = base_pay
        self.sales_incentive = sales_incentive

    def get_pay(self):
        return self.base_pay + self.sales_incentive


if __name__ == '__main__':
    john = SalesEmployee('John', 5000, 1500)
    print(john.get_pay())

    jane = Employee('Jane', 5000)
    print(jane.get_pay())
# Out:
# 6500
# 5000

# %%
class A:
    def __init__(self,name):
        self.name=name
a1=A("john")
a2=A("john")
